# %% [markdown]
# T1. On considère l'expérience aléatoire qui consiste à tirer uniformément et indépendamment deux entiers sur $[\![ 1, n ]\!]$, $n \in \mathbb{N}$.
#
# Il faut montrer que
# $$
# \mathcal{P}_n:=\mathbb{P}[P_n]=\frac{6}{\pi^2}+O\left(\frac{\ln n}{n}\right).
# $$
#
# a) L'événement totale $\Omega = \{\text{à tirer uniformément et indépendamment deux entiers}\}$ et on a
# $$
#     |\Omega| = \frac{ |[\![1,n]\!] \times [\![1,n]\!]|}{2!}=\frac{n^2}{2}
# $$
# parce que les deux entiers ne sont pas ordonnée. Également, notons que deux entiers $a$ et $b$ sont premiers entre eux ssi $PGCD(a,b)=PGCD(b,a)=1$ et donc $(a,b) \in A_n$ et $(b,a) \in A_n$. En revance, si $(a,b) \in A_n$, on a $(b,a) \in A_n$ et alors $a$ et $b$ sont entiers entre eux. C'est-à-dire,
# $$
# |A_n| = 2|P_n|
# $$
# et alors
# $$
# \mathcal{P}_n = \frac{|P_n|}{|\Omega_n|} = \frac{|A_n|}{n^2}.
# $$
# b) Soit $(a,b) \not\in A_n$. C'est-à-dire, $PGCD(a,b) >1$. Soit $p_i\mid PGCD(a,b)$, donc $p_i \mid a$ et $p_i \mid b$ et donc $(a,b) \in D_i \subset \bigcup_{i=1}^{\pi_n}D_i$.
#
# En revanche, si $(a,b) \in \bigcup_{i=1}^{\pi_n}D_i$, il existe $i \in [\![1,\pi(n)]\!]$ tel que $(a,b) \in D_i$, donc $p_i \mid a$ et $p_i \mid b$. À ce moment-là, on a $p_i|PGCD(a,b)$ et donc $(a,b) \not\in A_n$. Du coup on a montré que
# $$
# A_n^c = \bigcup_{i=1}^{\pi_n}D_i
# $$
# qui est equivalent que ce que on veut montrer.
# c) Par (b), on a
# $$
# \begin{aligned}
#     |A_n| &=  \left|[\![1,n]\!] \times [\![1,n]\!]\right| - \left|\left(\bigcup_{i=1}^{\pi_n}D_i\right)\right| \\
#            &= n^2 - \sum_{I \subset [\![1,\pi(n)]\!],\, I \ne \varnothing}(-1)^{|I|+1}\left|\bigcap_{i \in I}D_i\right| \\
#            &= n^2 + \sum_{I \subset [\![1,\pi(n)]\!],\, I \ne \varnothing}(-1)^{|I|}\left|\bigcap_{i \in I}D_i\right|
# \end{aligned}
# $$
# Pour $I \subset [\![1,\pi(n)]\!],\, I \ne \varnothing$, si on met $\ell = \prod_{i \in I}p_i$, on a $(-1)^{|I|}=\mu(\ell)$. En revanche, notons que $(a,b) \in \bigcap_{i \in I}D_i$ ssi $\ell|a$ et $\ell | b$. C'est-à-dire $a,b \in \{\ell,2\ell,\dots,\lfloor \frac{n}{\ell}\rfloor\ell\}$ et donc
# $$
#     |\bigcap_{i \in I}D_i| = |\{\ell,2\ell,\dots,\lfloor \frac{n}{\ell}\rfloor\ell\} \times \{\ell,2\ell,\dots,\lfloor \frac{n}{\ell}\rfloor\ell\}| = \left\lfloor \frac{n}{\ell} \right\rfloor^2
# $$
# Après, notons que pour $\ell \in [\![1,n]\!]$, $\mu(\ell)\ne 0$ ssi $\ell=\prod_{i \in I}p_i$ où $I \subset [\![1,\pi(n)]\!],\, I \ne \varnothing$ ou $\ell=1$. Donc
# $$
#     \sum_{\ell=1}^{n}\mu(\ell)\left\lfloor \frac{n}{\ell} \right\rfloor^2 = \sum_{\ell \in [\![1,n]\!]}^{\mu(\ell) \ne 0}\mu(\ell)\left\lfloor \frac{n}{\ell} \right\rfloor^2 = \sum_{I \subset [\![1,\pi(n)]\!],\, I \ne \varnothing}(-1)^{|I|}\left|\bigcap_{i \in I}D_i\right|+\mu(1)n^2 = |A_n|
# $$
#
# d) **Lemme.** Pour $s>1$, on a
# $$
# \sum_{n=1}^{\infty}\frac{\mu(n)}{n^s}=\frac{1}{\zeta(s)}.
# $$
# *Preuve.* Notons que
# $$
#     \begin{aligned}
#         \frac{1}{\zeta(s)} &= \prod_{i=1}^{\infty}\left(1-\frac{1}{p_i^s}\right) \\
#                            &= 1  -\sum_{i}\frac{1}{p_i^s} + \sum_{i<j}\frac{1}{p_i^s p_j^s} - \sum_{i<j<k}\frac{1}{p_i^s p_j^s p_k^s} + \\
#                            &= \sum_{n=1}^{\infty}\frac{\mu(n)}{n^s}
#     \end{aligned}
# $$
# $\square$
#
# Pour la question (d), soit $\{x\}=x-\lfloor x \rfloor$. Par exemple, $\{2.3\}=0.3$. Alors
# $$
#     \begin{aligned}
#         \mathcal{P}_n = \frac{1}{n^2}|A_n| &= \sum_{\ell=1}^{n}\frac{1}{n^2}\mu(\ell)\left\lfloor \frac{n}{\ell} \right\rfloor^2 \\
#             &= \frac{1}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left(\frac{n}{\ell}-\left\{\frac{n}{\ell}\right\}\right)^2 \\
#             &= \sum_{\ell=1}^{n}\mu(\ell)\frac{1}{\ell^2} -\frac{2}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left(\frac{n}{\ell}\right)\left\{\frac{n}{\ell}\right\} + \frac{1}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left\{\frac{n}{\ell}\right\}^2
#     \end{aligned}
# $$
# Et donc
# $$
#     \begin{aligned}
#         \mathcal{P}_n &= \left|\sum_{\ell=1}^{n}\mu(\ell)\frac{1}{\ell^2} -\frac{2}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left(\frac{n}{\ell}\right)\left\{\frac{n}{\ell}\right\} + \frac{1}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left\{\frac{n}{\ell}\right\}^2\right| \\
#                      &\leq \left|\sum_{\ell=1}^{n}\mu(\ell)\frac{1}{\ell^2}\right| + \left|\frac{2}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left(\frac{n}{\ell}\right)\left\{\frac{n}{\ell}\right\}\right| + \left|\frac{1}{n^2}\sum_{\ell=1}^{n}\mu(\ell)\left\{\frac{n}{\ell}\right\}^2\right|
#     \end{aligned}
# $$
# On utilise le fait que $|\mu(\ell)| \le 1$ et $\left\{\frac{n}{\ell}\right\} \le 1$ pour obtenir que
# $$
#     \begin{aligned}
#         \mathcal{P}_n &\leq \left|\frac{1}{\zeta(2)} - \sum_{\ell=n+1}^{\infty}\frac{1}{\ell^2}\right|+\left|\frac{2}{n}\sum_{\ell=1}^{n}\frac{1}{\ell}\right| + \left|\sum_{\ell=1}^{n}\frac{1}{n^2} \right| \\
#                       &\leq \frac{6}{\pi^2} + \sum_{\ell=n+1}^{\infty}\frac{1}{\ell^2} + \frac{2}{n}\sum_{\ell=1}^{n}\frac{1}{\ell} + \sum_{\ell=1}^{n}\frac{1}{n^2}
#     \end{aligned}
# $$
# Parce que $\sum_{\ell=n+1}^{\infty}\frac{1}{\ell^2} \sim \frac{1}{n}=O\left(\frac{\ln n}{n}\right)$ (considérons l'intégrale $\int_{n+1}^{\infty}\frac{1}{x^2}\mathrm{d}x$), $\frac{2}{n}\sum_{\ell=1}^{n}\frac{1}{\ell} \sim \frac{\ln n}{n}$ (considérons $\lim_{n\to\infty}\left(1+\frac{1}{2}+\dots+\frac{1}{n}-\ln{n}\right)=\gamma<\infty$) et $\sum_{\ell=1}^{n}\frac{1}{n^2}=\frac{1}{n}$, on obtient $\sum_{\ell=n+1}^{\infty}\frac{1}{\ell^2} + \frac{2}{n}\sum_{\ell=1}^{n}\frac{1}{\ell} + \sum_{\ell=1}^{n}\frac{1}{n^2}=O\left(\frac{\ln n}{n}\right)$ et donc
# $$
#     \mathcal{P}_n = \frac{6}{\pi^2}+O\left(\frac{\ln n}{n}\right)
# $$

# %% [markdown]
# #### S1. Mise en evidence de (An)
#
# Dans un premier temps, nous nous concentrons sur la méthode d'inversion qui permet d'obtenir des réalisations uniformes indépendantes sur $\![ 0, 1]\!$ à l'aide de réalisations uniformes indépendantes sur $[\![ 1, M ]\!]$.
# En effet, il s'agira d'écrire la fonction qui retourne 1 si x est égale à 0, la partie entière de $nx$ si $nx$ $\in \mathbb{N}$ et la partie entière de $nx$ plus 1 sinon, avec $x \in [ 0, 1 ]$.

# %%
# Des bibliothèques classiques de Python
import numpy as np
import scipy as scp
from scipy.integrate import quad
import scipy.stats as sps
import matplotlib.pyplot as plt
import random
import time
import tracemalloc

# %%
def realisation_uniforme(n):
    u=random.random()
    #u=random.randint(1,n)
    if (u==0):
        return 1
    elif(n*u-np.floor(n*u)==0):
         return n*u
    else:
         return np.floor(n*u)+1
    return u

# %% [markdown]
# Maintenant, nous comparons l'éfficacité de cette méthode à celle de la fonction randint()

# %%
randUniform = []
randInt = []
tracemalloc.start()

start_time = time.time()
for i in range(10000):
    randUniform.append(realisation_uniforme(10000))
end_time = time.time()

current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()
time_uniforme = (end_time - start_time) * 1000
memory_uniforme = peak / 1024

tracemalloc.start()
start_time = time.time()
for i in range(10000):
    randInt.append(random.randint(1,10000))
end_time = time.time()
tracemalloc.stop()
time_randint = (end_time - start_time) * 1000
memory_randint = peak / 1024

time_comparison = [time_uniforme,time_randint]
memory_comparison = [memory_uniforme,memory_randint]
label = ['Uniforme','randint']
plt.figure(figsize=(14,14))
plt.subplot(2,2,1)
plt.plot(range(10000),randUniform,'+',color='b')
plt.title("Distribution de la méthode d'inversion")
plt.subplot(2,2,2)
plt.plot(range(10000),randInt,'+',color='r')
plt.title("Distribution de randint")
plt.subplot(2, 2, 3)
plt.ylabel('Time')
plt.title('Time Comparison')
plt.bar(label,time_comparison,color=['b','r'])
plt.xlabel("Fonctions")
plt.ylabel("Temps (ms)")
plt.subplot(2,2,4)
plt.ylabel("Mémoire")
plt.title("Plus grand espace mémoire utilisé")
plt.bar(label,memory_comparison,color=['b','r'])
plt.xlabel("Functions")
plt.ylabel("Memory (KB)")
plt.show()

# %% [markdown]
# Les figures suivantes affichent les temps et les mémorires utilisées pour simuler 10000 réalisations uniformes sur $[\![1,10000]\!]$ en uilisant les deux méthodes.
#
# D'après les résultats d'exécution des deux méthodes, on conclut que la fonction randint() est la plus éfficace mais, les distributions obtenues par les deux méthodes sont quasiment pareilles.

# %% [markdown]
# Considérons la variable de Bernoulli $B_n$ qui renvoie 1 si le tirage des deux entiers compris entre 1 et $n$ ci-dessus donne des entiers premiers entre eux et 0 sinon.

# %%
def realisation_Bi(n):
   #   u1=random.randint(1,n)
   #   u2=random.randint(1,n)
     sample = random.sample(range(n+1),2)
     u1 = sample[0]
     u2 = sample[1]
     if(np.gcd(u1,u2)==1):
        return 1
     else:
        return 0

# %% [markdown]
# Considérons également $\mathcal{P}^M_n:=\frac{\sum_{i=1}^n B_n^i}{M}$, la moyenne empirique des $B_n^i$ suivant tous la même loi que $B_n$.

# %%
def probabilité(n,M):
    B=0
    for i in range(1,M+1):
        B=B+(realisation_Bi(n))
    return B/float(M)

# %% [markdown]
# $\mathcal{P}^M_n$ est un estimateur de ${P}_n$ qui d'après la loi des grands nombres, converge presque sûrement vers ${P}_n$ quand M tends vers l'infini. Mais puisque d'après ce qu'on a fait précédemment ${P}_n$ tends vers $\frac{6}{\pi^2}$, on devrait également voir que ${P}^M_n$ tend vers $\frac{6}{\pi^2}$ quand n et M tendent vers l'infini.

# %%
def affichage_proba(n,M):
    x=range(1,n+1)
    y=[]
    for i in x:
        y.append(probabilité(i,M))
    plt.title('Représentation de $\\mathcal{P}^M_n$ en fonction de $n$')
    plt.plot(x, y,label='La valeur donnée par l\'éstimateur')
    plt.axhline(y = 6/np.pi**2,linestyle='--',color='r',label='Valeur théorique $\\mathcal{P}_n=\\frac{6}{\\pi^2}$')
    plt.xlabel('n')
    plt.ylabel('$\\mathcal{P}^M_n$')
    plt.legend()
    plt.show()
    
affichage_proba(200,3000)

# %% [markdown]
# T2. Justifions que $\mathcal{P}_n^M \xrightarrow[M]{p.s.} \mathcal{P}_n$. D'après la loi de grands nombres, on a
# $$
# \lim_{n\to\infty}\mathcal{P}_n^M = \mathbb{E}(B_n^1) = \mathcal{P}_n \; \mathrm{p.s.}
# $$
# parce que $(B_n^i)_{i \in [\![1,M]\!]}$ est une suite de v.a. i.i.d. intégrables.
#
# Pour l' intervalle de confiance asymtotique, notons que
#
# $$
# \sqrt{M}\frac{\mathcal{P}_n^M-\mathcal{P}_n}{\sigma}\xrightarrow{\mathcal{L}}\mathcal{N}(0,1).
# $$
#
# Or, $\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)} \xrightarrow{\mathrm{p.s.}} \sqrt{\mathcal{P}_n(1-\mathcal{P}_n)}$. Et donc, selon le théorème de Skulsky,
#
# $$
# \sqrt{M}\frac{\mathcal{P}_n^M-\mathcal{P}_n}{\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)}}\xrightarrow{\mathcal{L}}\mathcal{N}(0,1).
# $$
#
# Pour que
#
# $$
# \mathbb{P}\left(\left|\sqrt{M}\frac{\mathcal{P}_n^M-\mathcal{P}_n}{\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)}}\right| \le A\right) = 0.95,
# $$
#
# on a $A=1,96$. Donc l'intervale de confiance asymptotique à 95% est donné par
# $$
# -\frac{1,96}{\sqrt{M}} \le \frac{\mathcal{P}_n-\mathcal{P}_n^M}{\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)}} \le \frac{1,96}{\sqrt{M}}
# $$
# ou autrement dit,
# $$
# \mathcal{P}_n \in \left[\frac{-1,96\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)}}{\sqrt{M}}+\mathcal{P}_n^M,\frac{1,96\sqrt{\mathcal{P}_n^M(1-\mathcal{P}_n^M)}}{\sqrt{M}}+\mathcal{P}_n^M \right]
# $$

# %% [markdown]
# T3. On cherche à quantifier $M$ de sorte que qu'avec une probabilité de 95%, l'estimateur ${P}^M_n$ de ${P}_n$ conduise à une erreur négligeable devant le reste dans $(\mathcal{A_n})$.\
# On a: ${P}^M_n-{P}_n\le 1.96\frac{\sqrt{{P}^M_n(1-{P}^M_n)}}{\sqrt M}\le \frac{1.96}{2\sqrt M}$.\
# Il faut donc trouver $M$ tel que $\frac{0.98}{\sqrt M}$ soit négligeable devant $\frac{\ln n}{n}$. On peut prendre M tel que $\frac{0.98}{\sqrt M}\le\frac{\ln n}{n^{1.01}}$ (qui est négligeable devant $\frac{\ln n}{n}$ en l'infini), c'est à dire $M(n)=\left\lfloor\frac {0.98^2 n^{2.02}}{(\ln{n})^2}\right\rfloor+1$ pour $n$ différent de 1.

# %% [markdown]
# T4. Notons que $\mathbb{E}[\bar{X}_M]=\mathbb{E}[X_1]$ et alors
# $$
# \begin{aligned}
# \mathbb{P}(|\bar{X}_M-\mathbb{E}(X_1)| \ge \varepsilon) &= \mathbb{P}(\bar{X}_M-\mathbb{E}(X_1) \ge \varepsilon) + \mathbb{P}(X_M-\mathbb{E}(X_1) \le -\varepsilon) \\
#                                                         &= \mathbb{P}(\bar{X}_M-\mathbb{E}(X_1) \ge \varepsilon) + \mathbb{P}(\mathbb{E}(X_1)-\bar{X}_M \ge \varepsilon) \\
#                                                         &= \mathbb{P}[\exp(\lambda(\bar{X}_M-\mathbb{E}(X_1))) \ge \exp(\lambda\varepsilon)] + \mathbb{P}[\exp(\lambda(\mathbb{E}(X_1)-\bar{X}_M)) \ge \exp(\lambda\varepsilon)] \\
#                                                         &\le \exp(-\lambda\varepsilon)\mathbb{E}[\exp(\lambda(\bar{X}_M-\mathbb{E}(X_1)))] + \exp(-\lambda\varepsilon)\mathbb{E}[\exp(\lambda(\mathbb{E}(X_1)-\bar{X}_M))] \\
#                                                         &= \exp(-\lambda\varepsilon)\mathbb{E}[\exp(\lambda(\bar{X}_M-\mathbb{E}(X_1)))] + \exp(-\lambda\varepsilon)\mathbb{E}[\exp(-\lambda(\bar{X}_M-\mathbb{E}(X_1)))]
# \end{aligned}
# $$
#
# Notons que
# $$
# \mathbb{E}[\exp(\lambda(\bar{X}_M-\mathbb{E}(X_1)))] = \mathbb{E}\left[\prod_{i=1}^{M}\exp\left(\frac{\lambda}{M}(X_i-\mathbb{E}(X_i))\right)\right]=\mathbb{E}\left[\exp\frac{\lambda}{M}(X_1-\mathbb{E}(X_1)\right]^M
# $$
#
# Alors il existe $\alpha > 0$ tel que
#
# $$
# \mathbb{E}[\exp(\lambda(\bar{X}_M-\mathbb{E}(X_1)))] = \left[\exp\frac{\lambda}{M}(X_1-\mathbb{E}(X_1)\right]^M \le \exp\left(\alpha\frac{\lambda^2}{2M^2}\right)^M=\exp\left(\alpha\frac{\lambda^2}{2M}\right)
# $$
#
# De la même façon, on trouve que
#
# $$
# \mathbb{E}[\exp(-\lambda(\bar{X}_M-\mathbb{E}(X_1)))] = \left[\exp\frac{-\lambda}{M}(X_1-\mathbb{E}(X_1)\right]^M \le \exp\left(\alpha\frac{\lambda^2}{2M}\right)
# $$
# Donc en résumé, on a
# $$
# \mathbb{P}(|\bar{X}_M-\mathbb{E}(X_1)| \ge \varepsilon) \le 2\exp\left(-\lambda\varepsilon+\alpha\frac{\lambda^2}{2M}\right),\;\forall\lambda\in\mathbb{R}
# $$
# Donc
# $$
# \mathbb{P}(|\bar{X}_M-\mathbb{E}(X_1)| \ge \varepsilon) \le \min_\lambda 2\exp\left(-\lambda\varepsilon+\alpha\frac{\lambda^2}{2M}\right) = 2\exp\left(-M\frac{\varepsilon^2}{2\alpha}\right)
# $$
#
# b) D'une part, d'après la question précédente, $\mathbb{P}(|\bar{X}_M-\mathbb{E}(X_1)|\le \varepsilon)\geq 1-2\exp\left(-M\frac{\varepsilon^2}{2\alpha}\right)$
# Ainsi, $1-2\exp\left(-M\frac{\varepsilon^2}{2\alpha}\right)\geq 0.95\Rightarrow \mathbb{P}(|\bar{X}_M-\mathbb{E}(X_1)|\le \varepsilon)\geq 0.95$. Or, $1-2\exp\left(-M\frac{\varepsilon^2}{2\alpha}\right)\geq 0.95 \iff \varepsilon \geq \sqrt{\frac{-2\alpha \ln(0.025)}{M}} $, $M \in \mathbb{N}^*$ .
# D'où un intervalle de confiance dans la question précédente est
# $\mathcal{J_{\alpha,M}}=[-\sqrt{\frac{-2\alpha \ln (0.025)}{M}}+\bar{X}_M, \bar{X}_M+\sqrt{\frac{-2\alpha \ln (0.025)}{M}}]\cap [0,1]$.
#
#
#
# D'autre part, en posant $Y_n=B_n-\mathbb{E}[B_n]$
#
# Par convexité de la fonction $( x \mapsto e^{\lambda x} )$, on a, $ e^{\lambda Y_n} \leq \frac{1 - Y_n}{1 - (-1)} e^{-\lambda } + \frac{Y_n - (-1)}{1 - (-1)} e^{\lambda} $
#
# En passant à l'espérance, on en déduit que
#
# $ \mathbb{E} \left( e^{\lambda Y_n} \right) \leq f(\lambda) = \frac{1}{2} e^{-\lambda} + \frac{1}{2} e^{\lambda}. $
#
# On pose
#
# $ 2\lambda = u, \quad \ln(f(\lambda)) = \psi(u)$, alors, $ \psi(u) = -\frac{1}{2}u + \ln \left( \frac{1}{2} + \frac{1}{2}e^u \right). $
#
# On remarque alors que $ \psi(0) = \psi'(0) = 0 $. De plus,
#
# $\psi''(u) = \frac{\left( \frac{1}{2} \right) \left( \frac{1}{2} \right) e^u}{\left( \frac{1}{2} + \frac{1}{2}e^u \right)^2} = \frac{\frac{1}{4} e^u}{\left( \frac{1 + e^u}{2} \right)^2} = \frac{\frac{1}{4} e^u}{\frac{(1 + e^u)^2}{4}} = \frac{e^u}{(1 + e^u)^2} \leq \frac{1}{4}. $
#
# Alors, en vertu de la formule de Taylor-Lagrange à l'ordre 1,
#
# $ \psi(u) = \psi(0) + \psi'(0)u + R_2(u) \leq \frac{u^2}{8}.$ D'où, $\ln(f(\lambda)) = \psi(2\lambda) \leq \frac{(2\lambda)^2}{8} = \frac{\lambda^2}{2}. $
#
# Ainsi,
#
# $ f(\lambda) \leq \exp \left( \frac{\lambda^2}{2} \right). $
#
# Par conséquent,
#
# $ \mathbb{E} \left[ e^{\lambda Y_n} \right] \leq \exp \left( \frac{\lambda^2}{2} \right). $
#
# On vient de montrer que $B_n$ vérifie la condition énoncée en début de la question T4, avec $\alpha=1$ d'où un intervalle de confiance à 95% de ${P}_n$ est  $\mathcal{J_M}=[-\sqrt{\frac{-2\ln (0.025)}{M}}+{P}^M_n, {P}^M_n+\sqrt{\frac{-2\ln (0.025)}{M}}]\cap [0,1]$.

# %% [markdown]
# ### S2. Mise en évidence des $(\mathcal{A_n})$ pour $n \in \{50,100,500,1000,2000\}$.
#
#
# On trouve $M(n)$ égale respectivement à 170, 497, 7040, 23109 et 77411.
#
# On peut dans un premier temps afficher les valeurs numérique des differents intervalles de confiance.
#
# Rapellons que la méthode de Monte Carlo a été utilisé dans la définition de la fonction probabilité(n,M). Nous allons utiliser cette fonction dans le cadre de cette question.

# %%
n=[50,100,500,1000,2000]
M=[170,497,7040,23109,77411]
PnM=[]
for i in range(5):
    PnM.append(probabilité(n[i],M[i]))
for i in range(5):
    intervalle_de_confiance=(-np.sqrt(-2*np.log(0.025)/M[i])+PnM[i], np.sqrt(-2*np.log(0.025)/M[i])+PnM[i])
    intervalle_asymptotique=(-1.96*np.sqrt(PnM[i]*(1-PnM[i])/M[i])+PnM[i], 1.96*np.sqrt(PnM[i]*(1-PnM[i])/M[i])+PnM[i])
    print("Pour "+"n = "+str(n[i])+" : ")
    print("Un intervalle de confiance à 95% est "+str(intervalle_de_confiance))
    print("Un intervalle de confiance asymptotique à 95% est "+str(intervalle_asymptotique))
# Out:
# Pour n = 50 :
# Un intervalle de confiance à 95% est (0.4210885019311621, 0.8377350274806026)
# Un intervalle de confiance asymptotique à 95% est (0.5568103885420425, 0.7020131408697222)
# Pour n = 100 :
# Un intervalle de confiance à 95% est (0.4636747210934115, 0.7073514358482382)
# Un intervalle de confiance asymptotique à 95% est (0.5422017412178265, 0.6288244157238233)
# Pour n = 500 :
# Un intervalle de confiance à 95% est (0.5731672980358624, 0.6379122474186831)
# Un intervalle de confiance asymptotique à 95% est (0.594123017529809, 0.6169565279247365)
# Pour n = 1000 :
# Un intervalle de confiance à 95% est (0.5904233185010019, 0.626158965457629)
# Un intervalle de confiance asymptotique à 95% est (0.6019974869056522, 0.6145847970529786)
# Pour n = 2000 :
# Un intervalle de confiance à 95% est (0.5992594771318513, 0.6187844701107885)
# Un intervalle de confiance asymptotique à 95% est (0.6055844365638704, 0.6124595106787695)

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
for i in range(5):
    plt.errorbar(n[i],PnM[i],yerr=np.sqrt(-2*np.log(0.025)/M[i]),fmt='o', label=f'n={n[i]}')
plt.xlabel('n')
plt.ylabel('Estimation de $\\mathcal{P}_n$')
plt.axhline(y = 6/np.pi**2, color = 'b',linestyle = '--',label= 'Valeur théorique $\\frac{6}{\\pi^2}$')
plt.title("Intervalles de confiance")
plt.legend()

plt.subplot(1,2,2)
for i in range(5):
    plt.errorbar(n[i],PnM[i],yerr=1.96*np.sqrt(PnM[i]*(1-PnM[i])/M[i]),fmt='o', label=f'n={n[i]}')
plt.xlabel('n')
plt.ylabel('Estimation de $\\mathcal{P}_n$')
plt.axhline(y = 6/np.pi**2, color = 'b',linestyle = '--',label='Valeur théorique $\\frac{6}{\\pi^2}$')
plt.legend()
plt.title("Intervalles de confiance asymptotique")
plt.show()

# %% [markdown]
# On remarque que $\frac{6}{\pi^2}$ est toujours dans les intervalles de confiance.

# %% [markdown]
# T5.
# * La distribution des nombres primes ne sont pas vraiment aléatoire.
# * Les variables aléatoires ne sont pas vraiment indépendantes.

# %% [markdown]
# T6. Parce que $\mathcal{B}_i$ sont indépendantes, on a immédiatement
# $$
# m(n) = \mathbb{E}(\Pi(n)) = \sum_{k=2}^{n}\mathbb{E}(\mathcal{B}_i) = \sum_{k=2}^{n}\frac{1}{\log k}
# $$
# et également
# $$
# \mathbb{V}(\Pi(n)) = \sum_{k=2}^{n}\mathbb{V}(\mathcal{B}_i) = \sum_{k=2}^{n}\frac{1}{\log k}\left(1-\frac{1}{\log k}\right)
# $$
# Par la définition de variance, on a
# $$
# \begin{aligned}
# \mathbb{V}(\Pi(n)) &= \sum_{k=2}^{n}\frac{1}{\log k}\left(1-\frac{1}{\log k}\right) \\
#                    &= \mathbb{E}(|\Pi(n)-m(n)|^2) \\
#                    &\ge \mathbb{E}(|\Pi(n)-m(n)|^2 \chi_{\{|\Pi(n)-m(n)|^2 \ge n^{4/3}\}}) \\
#                    &\ge n^{4/3}\mathbb{P}(|\Pi(n)-m(n)|^2 \ge n^{4/3})
# \end{aligned}
# $$
#
# Pour majorer la variance, notons que $\int_2^x \frac{1}{\log x}\left(1-\frac{1}{\log x}\right)dx = \frac{x}{\log x} - \frac{2}{\log 2}$ et donc $\sum_{k=2}^{n}\frac{1}{\log k}\left(1-\frac{1}{\log k}\right) \sim \frac{n}{\log n}$ ou autrement dit, $\sum_{k=2}^{n}\frac{1}{\log k}\left(1-\frac{1}{\log k}\right) \le C \frac{n}{\log n}$ pour certain $C>0$.
#
# Et nous déduisons que $\mathbb{P}(|\Pi(n)-m(n)|^2 \ge n^{4/3}) = \mathbb{P}(|\Pi(n)-m(n)| \ge n^{2/3}) \le C\frac{1}{n^{1/3}\log n}$. Donc
# $$
# 0 \le \lim_{n\to\infty}\mathbb{P}(|\Pi(n)-m(n)|^2 \ge n^{4/3}) \le \lim_{n\to\infty}C\frac{1}{n^{1/3}\log n} = 0
# $$
# et donc
# $$
# \lim_{n\to\infty}\mathbb{P}(|\Pi(n)-m(n)| < n^{2/3}) = \lim_{n\to\infty} [1 - \mathbb{P}(|\Pi(n)-m(n)| \ge n^{2/3})] = 1
# $$
#
# Pour $A_n = \{|\Pi(n^4)-m(n^4)| \ge n^{8/3}\}$, par l'inegalité que l'on vient d'obtenir,
# $$
# \mathbb{P}(A_n) \le C n^{-1/3}\log(n^4)^{-1} = C' n^{-4/3} \log(n)^{-1};\; C,C'>0.
# $$
# mais la série $\sum_{n=2}^{\infty}\frac{1}{n^{4/3}\log n}$ converge parce que $0 < \frac{1}{n^{4/3}\log n} < \frac{1}{n^{4/3}}$ et $\sum\frac{1}{n^{4/3}}$ converge. Alors $\sum_{n=2}^{\infty}\mathbb{P}(A_n)<\infty$ et puis $\mathbb{P}(\liminf_{n\to\infty} A_n^c)=1$ (Borel-Cantelli).
#
# Pour $B_k=\{|\Pi(k)-m(k)| \le Ck^{3/4}\}$, notons que
# $$
# B_{n^4} = \{|\Pi(n^4)-m(n^4)| \le C n^3\} \supset A_n^c
# $$
# et de même lorsque $k \in [\![n^4,(n+1)^4]\!]$, on a
# $$
# |\Pi(k)-m(k)| = |\Pi(k)-\Pi(n^4)|+|\Pi(n^4)-m(n^4)|+|m(k)-m(n^4)|
# $$
#
# Parce qu'il y a $O(n^3)$ entiers entre $k$ et $n^4$, on voit que $|\Pi(k)-\Pi(n^4)|=O(n^3)$ et $|m(k)-m(n^4)|=O(n^3)$. Lorsque $B_{n^4}$ est vrai, on sait que $|\Pi(n^4)-m(n^4)|\le Cn^3$ et donc $|\Pi(k)-m(k)|=O(n^3)$ aussi. Donc dans tous les cas, $B_k \supset A_n^c$ pour $k \in [\![n^4,(n+1)^4]\!]$ et donc $\bigcap_{m=n}^{\infty}B_m \supset \bigcap_{m=n}^{\infty}A_m^c$. Cela signifie que
# $$
# \liminf_{k}B_k \supset \liminf_{n}A_n^c \implies \mathbb{P}[\liminf_{k}B_k] = 1
# $$

# %% [markdown]
# T7. Rappelons le TCL de Lyapunov
# > **Théorème - Théorème central limite (Lyapunov).** Soit $(X_1,\dots,X_n)$ une suite de variables aléatoires tel que $\mu_i=\mathbb{E}[X_i]<\infty$ et $\sigma_i^2 = \mathbb{E}[X_i]$. Définissons
# $$
# s_n^2 = \sum_{i=1}^{n} \sigma_i^2.
# $$
# S'il existe $\delta > 0$ tel que
# $$
# \lim_{n \to \infty} \frac{1}{s_n^{2+\delta}}\sum_{i=1}^{n}\mathbb{E}[X_i-\mu_i|^{2.+\delta}] = 0,
# $$
# alors
# $$
# \frac{1}{s_n} \sum_{i=1}^{n}(X_i - \mu_i) \xrightarrow{\mathcal{L}}\mathcal{N}(0,1).
# $$
#
# Pour utiliser ce théorème, en définissant $X_n = \mathcal{B}_n$ et $X_0 = X_1 = 0$, il faut noter que $|X_n|$ est bornée par $1$ uniformément et donc
# $$
# \sum_{k=2}^{n}\frac{1}{s_n^3}\mathbb{E}[|X_k|^3] \le \sum_{k=2}^{n}\frac{1}{s_n^3}\mathbb{E}[|X_k|^2]=\frac{1}{s_n} \to 0\;(n\to\infty)
# $$
#
# Référence : Billingsley, Patrick (1995). Probability and Measure (3rd ed.). John Wiley & Sons.

# %% [markdown]
# T8. Nous allons utiliser le théorème de Kolmogorov (1929). [Kai Lai Chung, *A Course in Probability Theory*]
# > **Théorème.** Soit $\{X_n\}$ une suite de v.a. tel que $\mathbb{E}(X_n)=0$. Soit $S_n=\sum_{j=1}^{n}X_j$. Supposons que pour $s_n^2=\mathbb{V}(S_n)$, on a
# $$
# \sup_\omega |X_n(\omega)| = o \left(\frac{s_n}{\sqrt{\log\log s_n}}\right),
# $$
# on aura que, presque sûrement,
# $$
# \limsup_{n\to\infty}\frac{S_n}{\sqrt{2s_n^2\log\log s_n}}=1.
# $$
#
# Dans notre problème, on met $X_n = \mathcal{B}_n - \mathbb{E}(\mathcal{B}_n)$ pour $n \ge 2$ et $X_1 = 0$. On a $\sup|X_n| \le 1 = o \left(\frac{s_n}{\sqrt{\log\log s_n}}\right)$. On a immédiatement
# $$
# \limsup_{n\to\infty}\frac{\Pi(n)-m(n)}{\sqrt{2\mathbb{V}(\Pi(n))\log\log(\sqrt{\mathbb{V}(\Pi(n))})}}=1
# $$
# Rapellons que $\mathbb{V}(\Pi(n))= \mathbb{V}(S_n) = \frac{n}{\log n}+O(1)$ et donc
# $$
# \begin{aligned}
#     2\mathbb{V}(\Pi(n))\log\log(\sqrt{\mathbb{V}(\Pi(n))}) &= 2\left(\frac{n}{\log n}+O(1)\right)\log\log\sqrt{\frac{n}{\log n}+O(1)}.
# \end{aligned}
# $$
# Notons que
# $$
# \begin{aligned}
#     \lim_{n\to\infty}\frac{\log\log\sqrt{\frac{n}{\log n}+O(1)}}{\log\log(n)} &= \lim_{n\to\infty}\frac{\log\log\sqrt{\frac{n}{\log{n}}}}{\log\log n} \\
#                                                                                     &= \lim_{n\to\infty}\frac{\log\left(\frac{1}{2}\log\frac{n}{\log{n}}\right)}{\log\log n} \\
#                                                                                     &= \lim_{n\to\infty}\frac{-\log 2 + \log\log\frac{n}{\log{n}}}{\log\log n} \\
#                                                                                     &= \lim_{n\to\infty}\frac{-\log 2 + \log\log n - \log\log\log n}{\log\log n} \\
#                                                                                     &= \lim_{n\to\infty}\frac{-\log 2}{\log\log n} + \lim_{n\to\infty}\frac{\log\log n}{\log\log n} + \lim_{n\to\infty}\frac{\log\log\log n}{\log\log n} \\
#                                                                                     &= 1
# \end{aligned}
# $$
# et donc
# $$
# \lim_{n\to\infty}\frac{\sqrt{2\mathbb{V}(\Pi(n))\log\log\sqrt{\mathbb{V}(\Pi(n))}}}{\sqrt{2\left(\frac{n}{\log n}\right)\log\log n}} = \lim_{n\to\infty}\frac{\sqrt{2\left(\frac{n}{\log n} + O(1)\right)\log\log\sqrt{\frac{n}{\log n}+O(1)}}}{\sqrt{2\left(\frac{n}{\log n}\right)\log\log n}} = 1.
# $$
#
# Finalement,
# $$
# \begin{aligned}
# \limsup_{n\to\infty}\frac{\Pi(n)-\mathrm{Li(n)}}{\sqrt{2\frac{n}{\log n}\log\log n}} &= \limsup_{n\to\infty}\frac{\Pi(n)-m(n)+m(n)-\mathrm{Li}(n)}{\sqrt{2\frac{n}{\log n}\log\log n}} \\
#                                                                                      &= \limsup_{n\to\infty}\frac{\Pi(n)-m(n)+O(1)}{\sqrt{2\mathbb{V}(\Pi(n))\log\log\sqrt{\mathbb{V}(\Pi(n))}}} \\
#                                                                                      &= 1
# \end{aligned}
# $$
# Dans la même façon (en utilisant le théorème de Kolmogorov dans l'autre côté), on peut montrer que $\liminf_{n\to\infty}\frac{\Pi(n)-\mathrm{Li(n)}}{\sqrt{2\frac{n}{\log n}\log\log n}}=-1$, qui nous donne la limite que nous voulons.

# %% [markdown]
# #### S.3. Illustration des phénomènes abordés à la partie 2

# %%
#simulation des variables Bi
def Bi(i): 
    u=np.random.binomial(1,min(1, 1/np.log(i)))
    return u
#simulation des sommes Π(i)
def simuler_Pi(n):
    Pi=0
    for i in range(2,n+1):
        Pi=Pi+Bi(i)
    return Pi
#moyenne m(n)
def m(n):
    m=1
    for i in range(2,n+1):
        m=m+1/np.log(i)
    return m

def GenerateCramerPrime(n):
    k=[0]*(n+1)
    k[0]=0
    k[1]=0
    k[2]=1
    for p in range(3,n+1):
        k[p]=np.random.binomial(1,min(1, 1/np.log(p)))
    return k

# %% [markdown]
# Illustrons de la question T.6

# %%
n_values=range(6000)
simulate=[]
simulate1=[]
simulate2=[]
simulate3=[]
for k in n_values:
    simulations =simuler_Pi(k)
    simulations=np.abs(simulations-m(k))
    simulate.append(simulations)
    simulate1.append(0.15*k**(3/4))
    simulate2.append(0.25*k**(3/4))
    simulate3.append(0.2*k**(3/4))
plt.plot(n_values,simulate,'+',label='$|\\Pi(k)-m(k)|$')
plt.plot(n_values,simulate1,label='$0.15 k^{3/4}$')
plt.plot(n_values,simulate2,label='$0.20 k^{3/4}$')
plt.plot(n_values,simulate3,label='$0.25 k^{3/4}$')
plt.xlabel('k')
plt.title('$|\\Pi(k)-m(k)|$ c. $Ck^{3/4}$ pour $C=0.15,\\, 0.20,\\, 0.25$')
plt.legend()
plt.show()

# %% [markdown]
# On remarque que pour quelque $k_0$ assez grand, on a toujours que $|\Pi(k)-m(k)| \le C k^{3/4}$ pour tout $k>k_0$. C'est l'équivalence que $\mathbb{P}[\liminf_{k}B_k] = 1$.

# %% [markdown]
# Illustrons le phénomène de la question T.7

# %%
nbre_simulations = 2000
n_values = [100, 500, 5000, 9000] #différentes valeurs de n
index = 1
plt.figure(figsize=(20,20))
for n in n_values:
    plt.subplot(2,2,index)
    simulations = [simuler_Pi(n) for _ in range(nbre_simulations)] #crée un échantillon de Π(n) de taille nbre_simulations
    simulations=(simulations - m(n)) / np.sqrt(m(n)) #normalise l'échantillon de sorte à obtenir celui de (Π(n)-m(n))/√(m(n))
    # Affichage des résultats
    plt.hist(simulations, bins='auto', density=True, alpha=0.6, label=f'n = {n}')
    X = np.linspace(np.min(simulations), np.max(simulations), 500) # discrétise l'intervalle d'affichage
    plt.plot(X, sps.norm.pdf(X), "r", label="densité gaussienne $\\mathcal{N}(0,1)$") # trace la densité gaussienne.
    plt.title('Convergence en loi de $(\\Pi(n)-m(n))/\\sqrt{m(n)} \\to \\mathcal{N}(0,1)$')
    plt.xlabel('Valeurs normalisées')
    plt.ylabel('Densité de probabilité')
    plt.legend()
    index = index + 1
plt.show()

# %% [markdown]
# Visiblement, lorsque $n$ est assez grand, la densité empirique converge vers la loi normale centrée réduite.

# %%
#calcul de Li(n)
def f(x):
    return 1/np.log(x)
def Li(n):
    integrale = quad(f, 2, n)
    return integrale[0]

def toBeVerified(n):
    return (simuler_Pi(n)-Li(n)) / (np.sqrt(2 *n * np.log(np.log(n)) / np.log(n)))

# %%
samples = np.arange(3,1500) 
k = 15
dedans = 0;
dehors = 0;
for j in range(k):
    values = []
    for i in samples:
        #values.append(toBeVerified(i))
        val = toBeVerified(i)
        values.append(val)
        if(val>1 or val < -1):
            dehors = dehors + 1
        else:
            dedans = dedans + 1
    plt.plot(samples,values,'.')
plt.axhline(y=1,color='r')
plt.axhline(y=-1,color='r')
plt.title("Simulation de T8.")
plt.xlabel('n')
plt.ylabel('$(\\Pi(n)-Li(n)) / \\sqrt{2n\\log\\log{n}/\\log n}$')
plt.show()
print("Le nombres de valeurs dans [-1,1]: %d" %(dedans))
print("Le nombres de valeurs hors de [-1,1]: %d" %(dehors))
print( "%f des valeurs sont dedans" %(100*dedans/(dedans + dehors)))
# Out:
# Le nombres de valeurs dans [-1,1]: 21344
# Le nombres de valeurs hors de [-1,1]: 1111
# 95.052327 des valeurs sont dedans

# %% [markdown]
# On a calculé $(\Pi(n)-Li(n)) / \sqrt{2n\log\log{n}/\log n}$ entre 3 et 1500 15 fois chacune et on trouve que la grande majorité des valeurs sont distribuées en -1 et 1. C'est équivalent à dire que $\limsup_{n\to\infty}\frac{|\Pi(n)-\mathrm{Li(n)}|}{\sqrt{2\frac{n}{\log n}\log\log n}} =1$.

# %% [markdown]
# T9. Posons $E_m^\eta = \bigcap_{i=1}^{\lceil \eta \ln(m)^2 \rceil}\{\mathcal{B_{m+i}}=0\}$. Soit $M=\lceil \eta \ln(m)^2 \rceil$. Alors par définition, on a
# $$
# \mathbb{P}[E_m^\eta] = \prod_{k=1}^{M}\left(1-\frac{1}{\log (k+m)}\right)
# $$
#
# Alors a) est facile parce que
#
# $$
# \mathfrak{p}_{n+1} - \mathfrak{p}_n > \lceil\eta \log (\mathfrak{p})^2\rceil \ge \eta \log (\mathfrak{p})^2 \text{ pour un infinité de $n$ } \iff \text{ il y a un infinité de $n$ dans $E_m^\eta$. }
# $$
# et c'est équivalent à dire
# $$
# \mathbb{P}(\limsup\{\mathfrak{p}_{n+1}-\mathfrak{p}_n\}> \eta \log (\mathfrak{p}_n)^2) = \mathbb{P}(\limsup_m E_m^\eta)
# $$
#
# Pour b), rappelons que $\log(1+x)=x+O(x^2)$ et alors $1+x = \exp(x+O(x^2))$, et la question est équivalent à montrer que $\mathbb{P}(E_m^\eta)=\frac{O(1)}{m^\eta}$ Donc
# $$
# \begin{aligned}
# \mathbb{P}[E_m^\eta] &= \prod_{k=1}^{M}\left(1-\frac{1}{\log (k+m)}\right) \\
#                      &= \prod_{k=1}^{M}\exp\left(-\frac{1}{\log (k+m)}+O\left(\frac{1}{\log (k+m)}\right)^2\right) \\
#                      &= \exp\left(\sum_{k=1}^{M}\frac{-1}{\log (k+m)}+O\left(\sum_{k=1}^{M}\left(\frac{1}{\log (k+m)}\right)^2\right)\right)
# \end{aligned}
# $$
# Notons que
# $$
# \begin{aligned}
# \sum_{k=1}^{M}\left(\frac{1}{\log (k+m)}\right)^2 &< \sum_{k=1}^{M}\left(\frac{1}{\log (m)}\right)^2 \\
#                                                          &= \frac{\lceil \eta \log(m)^2\rceil}{\log(m)^2}
# \end{aligned}
# $$
# est bornée par un nombre determiné par $\eta$. Donc $O\left(\sum_{k=1}^{M}\left(\frac{1}{\log (k+m)}\right)^2\right)=O(1)$.
#
# Dans le même temps,
#
# $$
# \sum_{k=1}^{M}\frac{1}{\log(m+k)} = \frac{M}{\log(m+M+1)}-\sum_{k=1}^{M}k\left(\frac{1}{\log(m+k+1)}-\frac{1}{\log(m+k)}\right)=\eta\log(m)+O(1)
# $$
# Combinons tous les résultats qu'on vient d'obtenir, on a
# $$
# \mathbb{P}(E_m^\eta) = \frac{O(1)}{m^\eta}.
# $$
#
# Pour c), notons que lorsque $\eta>1$, on a
# $$
# \sum_{m=1}^{\infty}\mathbb{P}[E_m^\eta] \le \sum_{m=1}^{\infty}\frac{C_2}{m^\eta} < \infty
# $$
# et alors par Borel-Cantelli,
# $$
# \mathbb{P}(\limsup\{\mathfrak{p}_{n+1}-\mathfrak{p}_n\}> \eta \log (\mathfrak{p}_n)^2) = \mathbb{P}(\limsup_m E_m^\eta) = 0
# $$
#
# En revanche, lorsque $0 < \eta < 1$, posons $m_1 = 2$ et $m_{k+1} = m_k + \lceil \eta \log m_k \rceil$. Par le raisonment par récurrence, on a que $m_k < e^5k(\log k)^2$ pour tous les $k=1,2,\dots$. Dans ce cas,
# $$
# \sum_{k=1}^{\infty}\mathbb{P}[E_{m_k}^\eta] \ge  \sum_{k=1}^{\infty}\frac{C_1}{m_k^\eta} \ge \sum_{k=1}^{\infty}\frac{C_1}{(e^5 k (\log k)^2)^\eta}=\infty
# $$
#
# Parce que $(E_{m_k})_k$ sont indépendants, on vois que par Borel-Cantelli, $\mathbb{P}(\limsup_m E_m^\eta) = \mathbb{P}(\limsup_k E_{m_k}^\eta)=1$.
#
# Donc il y a un infinité de $n$ tel que $\mathfrak{p}_{n+1} - \mathfrak{p} > \eta \log(\mathfrak{p})^2$ pour tout $0<\eta < 1$. Donc
# $$
# \limsup_{n}\frac{\mathfrak{p}_{n+1}-\mathfrak{p}_n}{\log(\mathfrak{p_n})^2}=1
# $$
# presque sûrement.

# %%
def GenerateCramerPrime(n):
    k=[0]*(n+1)
    k[0]=0
    k[1]=0
    k[2]=1
    for p in range(3,n+1):
        k[p]=np.random.binomial(1,min(1, 1/np.log(p)))
    return k
def valeurs(arr):
    result = []
    p1 = 2
    p2 = p1
    for i in range(3,len(arr)):
        p2 = p2 + 1 
        if(arr[i]==0 and arr[i-1] == 1):
            p1 = p2 - 1
        if(arr[i]==1):
            if(arr[i-1]==0):
                result.append((p2-p1)/np.log(p1)**2)
            if(arr[i-1]==1):
                p1 = p2
    return result

N = 10000
k = 500
for i in range(k):
    val = valeurs(GenerateCramerPrime(N))
    plt.plot(range(len(val)),val,'.')
plt.axhline(y=1,color='b')
plt.title("Simulation de T9")
plt.xlabel("$\\mathfrak{p}_n$")
plt.ylabel("$(\\mathfrak{p}_{n+1} - \\mathfrak{p}_n) / \\log (\\mathfrak{p}_n)^2$")
plt.show()

# %% [markdown]
# On a calculé $(\mathfrak{p}_{n+1} - \mathfrak{p}_n) / \log (\mathfrak{p}_n)^2$ entre 0 et 10000, 500 fois chacune et on trouve que la grande majorité des valeurs sont distribuées entre 0 et 1. C'est équivalent à dire que $
# \limsup_{n}\frac{\mathfrak{p}_{n+1}-\mathfrak{p}_n}{\log(\mathfrak{p_n})^2}=1
# $.
